# %% [markdown]
# # COS Expenditure Analysis

# %%
import pandas as pd

raw_df = pd.read_csv("cos_expenditure.csv")
raw_df
# Out:
#      Doc. No. (GL View) Posting date                    Item Text  \
# 0            2600096964   03.11.2020       ILLAROO RD COS PAYMENT
# 1            2600096967   04.11.2020    CAMBEWARRA PS COS PAYMENT
# 2            2600096969   03.11.2020  KANGAROO VALLEY COS PAYMENT
# 3            2600096973   03.11.2020   NORTH NOWRA PS COS PAYMENT
# 4            2600096975   11.11.2020     BOMADERRY PS COS PAYMENT
# ..                  ...          ...                          ...
# 233          6500039712   01.09.2020                            #
# 234          6500039712   01.09.2020                            #
# 235          6500039712   01.09.2020                            #
# 236          6500039712   01.09.2020                            #
# 237          6500039712   01.09.2020                            #
#
#      G/L Account            Unnamed: 4  Fund    Cost Center        Unnamed: 7  \
# 0         522874  General Staff Traing  6100  1000/68448101  8448-ED DELIVERY
# 1         522874  General Staff Traing  6100  1000/68448101  8448-ED DELIVERY
# 2         522874  General Staff Traing  6100  1000/68448101  8448-ED DELIVERY
# 3         522874  General Staff Traing  6100  1000/68448101  8448-ED DELIVERY
# 4         522874  General Staff Traing  6100  1000/68448101  8448-ED DELIVERY
# ..           ...                   ...   ...            ...               ...
# 233       500006     Teaching Salaries  6100  1000/68448101  8448-ED DELIVERY
# 234       500044   Leave Load- Sch bsd  6100  1000/68448101  8448-ED DELIVERY
# 235       503337  Super Defined Contbn  6100  1000/68448101  8448-ED DELIVERY
# 236       504449           Payroll Tax  6100  1000/68448101  8448-ED DELIVERY
# 237       504453  Payroll Tax Super DC  6100  1000/68448101  8448-ED DELIVERY
#
#     WBS Element Unnamed: 9  Internal Order                   Unnamed: 11  \
# 0             #          #      2001018971  NORTH SHOALHAVEN COS PROJECT
# 1             #          #      2001018971  NORTH SHOALHAVEN COS PROJECT
# 2             #          #      2001018971  NORTH SHOALHAVEN COS PROJECT
# 3             #          #      2001018971  NORTH SHOALHAVEN COS PROJECT
# 4             #          #      2001018971  NORTH SHOALHAVEN COS PROJECT
# ..          ...        ...             ...                           ...
# 233           #          #      2001018971  NORTH SHOALHAVEN COS PROJECT
# 234           #          #      2001018971  NORTH SHOALHAVEN COS PROJECT
# 235           #          #      2001018971  NORTH SHOALHAVEN COS PROJECT
# 236           #          #      2001018971  NORTH SHOALHAVEN COS PROJECT
# 237           #          #      2001018971  NORTH SHOALHAVEN COS PROJECT
#
#      Funds\nReceived Fund Consumed
# 0                NaN    (6,720.00)
# 1                NaN    (4,000.00)
# 2                NaN      (960.00)
# 3                NaN    (4,160.00)
# 4                NaN    (7,040.00)
# ..               ...           ...
# 233              NaN        366.84
# 234              NaN          4.92
# 235              NaN         39.90
# 236              NaN         19.98
# 237              NaN          1.92
#
# [238 rows x 14 columns]

# %%
# Remove unwanted cols
df = raw_df.drop(columns=["G/L Account", "Fund", "Unnamed: 7", "WBS Element", "Unnamed: 9", "Internal Order", "Unnamed: 11"])
df = df.rename(columns={"Doc. No. (GL View)": "id", "Posting date": "date", "Item Text": "item", "Unnamed: 4": "category", "Cost Center": "code", "Funds\nReceived": "in", "Fund Consumed": "out"})
df["category"].value_counts()
# Out:
# Payroll Tax             45
# Leave Load- Sch bsd     45
# Payroll Tax Super DC    45
# Super Defined Contbn    45
# Teaching Salaries       36
# SASS Salaries           10
# General Staff Traing     8
# Sick Leave               3
# Meeting Exp Catering     1
# Name: category, dtype: int64

# %%
# nothin in the "in" column so move negative "out" values to "in"
print(df[df["in"] > 0].value_counts())

def formatter(x):
    if x[0] == "(" and x[-1] == ")":
        return f"-{x[1:-2].replace(',', '')}"
    return x

df["out"] = pd.to_numeric(df["out"].apply(formatter), errors="coerce")
df
# Out:
# Series([], dtype: int64)
#              id        date                         item  \
# 0    2600096964  03.11.2020       ILLAROO RD COS PAYMENT
# 1    2600096967  04.11.2020    CAMBEWARRA PS COS PAYMENT
# 2    2600096969  03.11.2020  KANGAROO VALLEY COS PAYMENT
# 3    2600096973  03.11.2020   NORTH NOWRA PS COS PAYMENT
# 4    2600096975  11.11.2020     BOMADERRY PS COS PAYMENT
# ..          ...         ...                          ...
# 233  6500039712  01.09.2020                            #
# 234  6500039712  01.09.2020                            #
# 235  6500039712  01.09.2020                            #
# 236  6500039712  01.09.2020                            #
# 237  6500039712  01.09.2020                            #
#
#                  category           code  in      out
# 0    General Staff Traing  1000/68448101 NaN -6720.00
# 1    General Staff Traing  1000/68448101 NaN -4000.00
# 2    General Staff Traing  1000/68448101 NaN  -960.00
# 3    General Staff Traing  1000/68448101 NaN -4160.00
# 4    General Staff Traing  1000/68448101 NaN -7040.00
# ..                    ...            ...  ..      ...
# 233     Teaching Salaries  1000/68448101 NaN   366.84
# 234   Leave Load- Sch bsd  1000/68448101 NaN     4.92
# 235  Super Defined Contbn  1000/68448101 NaN    39.90
# 236           Payroll Tax  1000/68448101 NaN    19.98
# 237  Payroll Tax Super DC  1000/68448101 NaN     1.92
#
# [238 rows x 7 columns]

# %%
import numpy as np
df["in"] = df[df["out"] < 0]["out"].abs()
df["out"] = df["out"].apply(lambda n: n if n > 0 else np.nan)
#df["id"].value_counts()
df[df["item"] == "KERRY WILLIAMS INV-2 2.11.2020"]
# Out:
#            id        date                            item  \
# 8  5303961060  03.11.2020  KERRY WILLIAMS INV-2 2.11.2020
#
#                category           code  in  out
# 8  General Staff Traing  1000/68448101 NaN  NaN

# %%
sum_df = df.groupby("id").sum()
sum_df
# Out:
#                 in      out
# id
# 2600096964  6720.0     0.00
# 2600096967  4000.0     0.00
# 2600096969   960.0     0.00
# 2600096973  4160.0     0.00
# 2600096975  7040.0     0.00
# 2600097324  1920.0     0.00
# 2600097326  2720.0     0.00
# 3200174138     0.0   114.54
# 5303961060     0.0     0.00
# 6400093727     0.0   541.50
# 6400094403     0.0   520.89
# 6400095370     0.0  1083.00
# 6400096782     0.0   520.89
# 6400097592     0.0  1083.00
# 6400097597     0.0   269.37
# 6400102745     0.0   520.89
# 6400103212     0.0   269.40
# 6400104860     0.0  1041.78
# 6400105717     0.0  1041.71
# 6400106185     0.0   673.50
# 6400107631     0.0   520.86
# 6400109648     0.0   433.20
# 6400110640     0.0  1083.00
# 6400111746     0.0  1083.00
# 6400115496     0.0   974.70
# 6400116373     0.0  1083.00
# 6400118425     0.0   649.80
# 6400119607     0.0   433.20
# 6400122459     0.0  1083.00
# 6400123444     0.0  1083.00
# 6400124394     0.0   138.07
# 6400125923     0.0   520.89
# 6400126084     0.0   414.21
# 6400126339     0.0  1083.00
# 6400127824     0.0  1083.00
# 6400128473     0.0   276.14
# 6400129924     0.0   649.80
# 6400130718     0.0   414.21
# 6400131235     0.0   433.20
# 6400132379     0.0   276.14
# 6400134227    91.6    91.64
# 6500026317     0.0   584.94
# 6500026634   584.7     0.00
# 6500032101     0.0   108.30
# 6500032417   108.0     0.00
# 6500034145     0.0   324.90
# 6500034385   324.6     0.00
# 6500035607     0.0   649.92
# 6500035786   649.7     0.00
# 6500037273     0.0   682.43
# 6500037543   682.2     0.00
# 6500038077     0.0   108.59
# 6500038366   108.3     0.00
# 6500039580   433.4     0.00
# 6500039712     0.0   433.56

# %%
# add dates back in
def id_date(id):
    return df[df["id"] == id]["date"].iloc[0]

sum_df["date"] = pd.to_datetime(sum_df.index.map(id_date), format="%d.%m.%Y")
sum_df.sort_values(by=["date"], inplace=True)
sum_df
# Out:
#                 in      out       date
# id
# 6500026317     0.0   584.94 2020-02-01
# 6400093727     0.0   541.50 2020-02-06
# 6400095370     0.0  1083.00 2020-02-20
# 6400094403     0.0   520.89 2020-02-20
# 6500026634   584.7     0.00 2020-03-01
# 6400097597     0.0   269.37 2020-03-05
# 6400097592     0.0  1083.00 2020-03-05
# 6400096782     0.0   520.89 2020-03-05
# 6400103212     0.0   269.40 2020-03-19
# 6400102745     0.0   520.89 2020-03-19
# 6400104860     0.0  1041.78 2020-03-19
# 6400106185     0.0   673.50 2020-04-02
# 6400105717     0.0  1041.71 2020-04-02
# 6400107631     0.0   520.86 2020-04-16
# 6400109648     0.0   433.20 2020-04-30
# 6500032101     0.0   108.30 2020-05-01
# 3200174138     0.0   114.54 2020-05-05
# 6400110640     0.0  1083.00 2020-05-14
# 6400111746     0.0  1083.00 2020-05-28
# 6500032417   108.0     0.00 2020-06-01
# 6500034145     0.0   324.90 2020-06-01
# 6400115496     0.0   974.70 2020-06-11
# 6400116373     0.0  1083.00 2020-06-25
# 6500035607     0.0   649.92 2020-07-01
# 6500034385   324.6     0.00 2020-07-01
# 6400118425     0.0   649.80 2020-07-09
# 6400119607     0.0   433.20 2020-07-23
# 6500035786   649.7     0.00 2020-08-01
# 6500037273     0.0   682.43 2020-08-01
# 6500038077     0.0   108.59 2020-08-01
# 6400122459     0.0  1083.00 2020-08-06
# 6400123444     0.0  1083.00 2020-08-20
# 6400124394     0.0   138.07 2020-08-20
# 6500037543   682.2     0.00 2020-09-01
# 6500038366   108.3     0.00 2020-09-01
# 6500039712     0.0   433.56 2020-09-01
# 6400125923     0.0   520.89 2020-09-03
# 6400126084     0.0   414.21 2020-09-03
# 6400126339     0.0  1083.00 2020-09-03
# 6400128473     0.0   276.14 2020-09-17
# 6400127824     0.0  1083.00 2020-09-17
# 6400129924     0.0   649.80 2020-10-01
# 6500039580   433.4     0.00 2020-10-01
# 6400130718     0.0   414.21 2020-10-01
# 6400131235     0.0   433.20 2020-10-15
# 6400132379     0.0   276.14 2020-10-29
# 6400134227    91.6    91.64 2020-10-29
# 5303961060     0.0     0.00 2020-11-03
# 2600096973  4160.0     0.00 2020-11-03
# 2600096969   960.0     0.00 2020-11-03
# 2600096964  6720.0     0.00 2020-11-03
# 2600096967  4000.0     0.00 2020-11-04
# 2600096975  7040.0     0.00 2020-11-11
# 2600097326  2720.0     0.00 2020-11-16
# 2600097324  1920.0     0.00 2020-11-16

# %%
# add some type of category based on mapping id ranges (?) and maybe even specific ids if known


def id_centre(id):
    if id < 3000000000:
        return "INCOME"
    if id < 4000000000:
        return "MEETING"
    if id < 5000000000:
        return "UNKNOWN"
    if id < 6000000000:
        return "SUPPLIER"
    return "PEOPLE"

sum_df["centre"] = sum_df.index.map(id_centre)


def id_category(id):
    return df[df["id"] == id]["category"].iloc[0]
        
sum_df["category"] = sum_df.index.map(id_category)
sum_df.to_csv("cos_costs_transformed.csv")

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

plotdf = sum_df[sum_df["out"] > 0].groupby("category").sum()
values = plotdf["out"]
labels = plotdf.index
amount_sum = plotdf["out"].sum()

def dollar_value(val):
    return f"${int(np.round(val/100*amount_sum))}"

fig1, ax1 = plt.subplots(figsize=(11,6))
ax1.pie(values, labels=plotdf.index, autopct=dollar_value)
ax1.axis('equal')
plt.title('Cost Categories')
plt.show()
